# %%
from PIL import Image
img=Image.open("image.jpg")
rgb_img=img.convert('RGB')
rgb_img.save("image_rgb.jpg")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 from PIL import Image
# ----> 2 img=Image.open("image.jpg")
#       3 rgb_img=img.convert('RGB')
#       4 rgb_img.save("image_rgb.jpg")
#
# File c:\Users\thoma\OneDrive\Documents\Documents\Programming\Color_gen\.venv\Lib\site-packages\PIL\Image.py:3639, in open(fp, mode, formats)
#    3637 if is_path(fp):
#    3638     filename = os.fspath(fp)
# -> 3639     fp = builtins.open(filename, "rb")
#    3640     exclusive_fp = True
#    3641 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'image.jpg'

# %%
#Downsizing image
rgb_img
